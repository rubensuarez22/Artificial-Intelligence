# %%
from typing import List, Tuple, Dict, Callable
import random

# %%
# Genome and Population Types
Genome = List[str]
Population = List[Genome]

# %%
subway_network = {
    "Tacubaya": [("Tacuba", 5), ("Balderas", 6), ("Centro médico", 3), ("Mixcoac", 3)],
    "Balderas": [("Salto del agua", 1), ("Tacubaya", 6), ("Hidalgo", 2), ("Centro médico", 3)],
    "Salto del agua": [("Pino Suárez", 2), ("Balderas", 1), ("Bellas artes", 2), ("Chabacano", 3)],
    "Pino Suárez": [("Candelaria", 2), ("Salto del agua", 2), ("Bellas artes", 3), ("Chabacano", 2)],
    "Candelaria": [("San Lázaro", 1), ("Pino Suárez", 2), ("Morelos", 1), ("Jamaica", 2)],
    "San Lázaro": [("Candelaria", 1), ("Morelos", 1), ("Oceanía", 3), ("Gómez Farías", 4)],
    "Gómez Farías": [("Pantitlán", 2), ("San Lázaro", 4)],
    "Pantitlán": [("Gómez Farías", 2), ("Oceanía", 3), ("Jamaica", 5)],
    "Tasqueña": [("Ermita", 1)],
    "Ermita": [("Zapata", 3),("Atlalilco", 2), ("Chabacano",6)],
    "Chabacano": [("Ermita", 6), ("Centro médico", 2), ("Jamaica", 1), ("Pino Suárez",2)],
    "Bellas Artes": [("Pino Suárez", 3), ("Salto del agua", 2), ("Garibaldi",1), ("Hidalgo",1)],
    "Hidalgo": [("Bellas Artes", 1), ("Guerrero", 1), ("Balderas", 2), ("Tacuba", 7)],
    "Tacuba": [("Cuatro caminos", 1), ("Hidalgo", 7), ("El Rosario", 4), ("Tacubaya", 5)],
    "Cuatro caminos": [("Tacuba", 1)],
    "Universidad": [("Zapata", 2)],
    "Zapata": [("Universidad", 2), ("Ermita",3), ("Mixcoac",3), ("Centro médico",4)],
    "Centro médico":  [("Zapata", 4), ("Tacubaya",3), ("Chabacano",2), ("Balderas",3)],
    "Guerrero":  [("Hidalgo",1 ), ("Garibaldi",1), ("La raza",2)],
    "La raza": [("Guerrero",2 ), ("Consulado", 3), ("Instituto del Petróleo",2), ("Deportivo 18 de Marzo", 2 )],
    "Deportivo 18 de Marzo": [("La raza", 2), ("Indios verdes",1), ("Martín Carrera",2), ("Instituto del Petróleo",2)],
    "Indios verdes": [("Deportivo 18 de Marzo", 2)],
    "Estación IA": [("Atlalilco", 6 ), ("Chabacano",2), ("Jamaica",1)],
    "Jamaica": [("Estación IA",1 ), ("Chabacano",1), ("Candelaria",2), ("Pantitlán", 5)],
    "Morelos": [("Candelaria",1 ), ("San Lázaro",1), ("Garibaldi",3), ("Consulado",2)],
    "Consulado": [("Morelos", 2 ), ("Oceanía", 3), ("La raza",3), ("Martín Carrera",3)],
    "Martín Carrera": [("Consulado", 3 ), ("Deportivo 18 de Marzo",2)],
    "Oceanía": [("Pantitlán", 3 ), ("San Lázaro", 3), ("Ciudad Azteca",1), ("Consulado",3)],
    "Instituto del Petróleo": [("La raza",2 ), ("Politécnico",1), ("Deportivo 18 de Marzo",2), ("El Rosario",6)],
    "El Rosario": [("Instituto del Petróleo", 6), ("Tacuba", 4)],
    "Barranca del muerto": [("Mixcoac",1 )],
    "Mixcoac": [("Barranca del muerto",1 ), ("Zapata",3), ("Tacubaya",3)],
    "Atlalilco": [("Tláhuac",1 ), ("Ermita",2), ("Estación IA",6)],
    "Garibaldi": [("Bellas artes",1 ), ("Guerrero",1), ("Morelos",3)],
    "Ciudad Azteca":[("Oceanía",1 )],
    "Tláhuac": [("Atlalilco",1 )]
}

# %%
def generate_route(start_station: str, end_station: str) -> Genome:
    """ Randomly generates a route from start to end station. """
    route = [start_station]
    while route[-1] != end_station:
        next_stops = subway_network.get(route[-1], [])
        if not next_stops:
            break
        next_stop = random.choice(next_stops)[0]
        route.append(next_stop)
    return route

# %%
def calculate_fitness(route: Genome, end_station: str) -> int:
    """ Calculates the total travel time for the route, penalizes incomplete routes. """
    time = 0
    for i in range(len(route) - 1):
        for connection in subway_network[route[i]]:
            if connection[0] == route[i + 1]:
                time += connection[1]
                break
        else:
            return float('inf')  # Penalize if route does not connect
    if route[-1] != end_station:
        return float('inf')  # Penalize if route does not reach the end station
    return time

# %%
def select_parents(population: Population, fitness_func: Callable[[Genome], int]) -> Tuple[Genome, Genome]:
    """ Selects parent routes based on fitness using tournament selection. """
    def tournament_select():
        contenders = random.sample(population, 3)
        return min(contenders, key=fitness_func)

    return tournament_select(), tournament_select()

# %%
def crossover(parent1: Genome, parent2: Genome) -> Tuple[Genome, Genome]:
    """ Combines routes from two parents to create new routes using single point crossover,
    ensuring that the start station remains the same. """
    min_length = min(len(parent1), len(parent2))
    if min_length > 2:
        crossover_point = random.randint(2, min_length - 1)  # Start from index 2 to keep the start station
        child1 = [parent1[0]] + parent1[1:crossover_point] + parent2[crossover_point:]
        child2 = [parent2[0]] + parent2[1:crossover_point] + parent1[crossover_point:]
        return child1, child2
    return parent1, parent2

# %%
def mutate(route: Genome, end_station: str, mutation_rate: float = 0.1) -> Genome:
    """ Randomly mutates a route, ensuring that the start station is preserved. """
    if random.random() < mutation_rate:
        if len(route) > 2:
            mutation_point = random.randint(2, len(route) - 1)  # Start from index 2 to keep the start station
            new_subroute = generate_route(route[mutation_point - 1], end_station)
            route = route[:mutation_point - 1] + new_subroute
    return route

# %%
def genetic_algorithm( end_station: str, population_size: int, generations: int, mutation_rate: float) -> Genome:
    """ Runs the genetic algorithm to find the best route. """
    stations = list(subway_network.keys())  # Get a list of all stations
    start_station = random.choice(stations)
    
    population = [generate_route(start_station, end_station) for _ in range(population_size)]
    fitness_func = lambda route: calculate_fitness(route, end_station)

    for generation in range(generations):
        population = sorted(population, key=fitness_func)
        best_route = population[0]
        print(f"Generation {generation}, Route taken: {best_route} Best Fitness = {fitness_func(population[0])}")

        if fitness_func(population[0]) == 0:
            break

        new_population = population[:2]  # Elitism: keep the best 2 routes
        while len(new_population) < population_size:
            parent1, parent2 = select_parents(population, fitness_func)
            child1, child2 = crossover(parent1, parent2)
            new_population.extend([mutate(child1, end_station, mutation_rate), mutate(child2, end_station, mutation_rate)])
        population = new_population

    return population[0]

# %%
end_station = "San Lázaro"
best_route = genetic_algorithm(end_station, 100, 100, 0.1)
print("Best Route:", best_route)
print("Travel Time:", calculate_fitness(best_route, end_station))
# Out:
# Generation 0, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 22
# Generation 1, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 22
# Generation 2, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 22
# Generation 3, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 22
# Generation 4, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 22
# Generation 5, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 6, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 7, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 8, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 9, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 10, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 11, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 12, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 13, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 14, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 15, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 16, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 17, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 18, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 19, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 20, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 21, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 22, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 23, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 24, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 25, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 26, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 27, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 28, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 29, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 30, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 31, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 32, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 33, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 34, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 35, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 36, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 37, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 38, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 39, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 40, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 41, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 42, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 43, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 44, Route taken: ['El Rosario', 'Instituto del Petróleo', 'Deportivo 18 de Marzo', 'Indios verdes', 'Deportivo 18 de Marzo', 'Martín Carrera', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 19
# Generation 45, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 46, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 47, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 48, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 49, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 50, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 51, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 52, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 53, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 54, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Oceanía', 'San Lázaro'] Best Fitness = 17
# Generation 55, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 56, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 57, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 58, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 59, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 60, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 61, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 62, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 63, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 64, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 65, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 66, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 67, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 68, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 69, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 70, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 71, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 72, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 73, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 74, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 75, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 76, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 77, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 78, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 79, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 80, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 81, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 82, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 83, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 84, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 85, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 86, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 87, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 88, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 89, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 90, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 91, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 92, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 93, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 94, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 95, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 96, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 97, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 98, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Generation 99, Route taken: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro'] Best Fitness = 14
# Best Route: ['El Rosario', 'Instituto del Petróleo', 'La raza', 'Consulado', 'Morelos', 'San Lázaro']
# Travel Time: 14
